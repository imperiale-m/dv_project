# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the GeoJSON file
gdf = gpd.read_file('./CNTR_RG_10M_2016_4326.geojson')
# gdf = gpd.read_file('./COAS_RG_10M_2021_4326.geojson')
# gdf = gpd.read_file('./CNTR_LB_2016_4326.geojson')
# Plot the data
gdf.plot(figsize = (10,10))

# Show the plot
plt.show()
